# %% [markdown]
# # Quantitative Momentum Strategy
#
# "Momentum investing" means investing in the stocks that have increased in price the most.
#
# For this project, we're going to build an investing strategy that selects the 50 stocks with the highest price momentum. From there, we will calculate recommended trades for an equal-weight portfolio of these 50 stocks.
#
#
# ## Library Imports
#
# The first thing we need to do is import the open-source software libraries that we'll be using in this tutorial.

# %%
import pandas as pd
import numpy as np 
import xlsxwriter 
import requests
import math
from scipy import stats

# %% [markdown]
# ## Importing Our List of Stocks
#
# As before, we'll need to import our list of stocks and our API token before proceeding. Make sure the `.csv` file is still in your working directory and import it with the following command:

# %%
from secrets import IEX_CLOUD_SANDBOX_API_TOKEN
stocks_df = pd.read_csv('sp_500_stocks.csv')
stocks_df.columns
# Out:
# Index(['Ticker'], dtype='object')

# %% [markdown]
# ## Making Our First API Call
#
# It's now time to make the first version of our momentum screener!
#
# Retrieve price and one-year stock returns

# %%
base_url="https://sandbox.iexapis.com"
params={"token":IEX_CLOUD_SANDBOX_API_TOKEN}
response = requests.get(f"{base_url}/stable/stock/fb/stats", params=params)
response.json()
# "GET /stock/{symbol}/stats/{stat?}"
# find price and one year stock returns in batch, lets do simple fisrt
# Out:
# {'companyName': 'Facebook Inc',
#  'marketcap': 946531744371,
#  'week52high': 340.2,
#  'week52low': 201.86,
#  'week52highSplitAdjustOnly': 347.32,
#  'week52lowSplitAdjustOnly': 210.61,
#  'week52change': 0.5043959521420666,
#  'sharesOutstanding': 2482330304,
#  'float': 0,
#  'avg10Volume': 19076703,
#  'avg30Volume': 19740140,
#  'day200MovingAvg': 285.47,
#  'day50MovingAvg': 315.2,
#  'employees': 52838,
#  'ttmEPS': 11.91,
#  'ttmDividendRate': 0,
#  'dividendYield': 0,
#  'nextDividendDate': '0',
#  'exDividendDate': '0',
#  'nextEarningsDate': '2021-07-14',
#  'peRatio': 28.095413168946045,
#  'beta': 1.2560037460406996,
#  'maxChangePercent': 7.461107248906546,
#  'year5ChangePercent': 1.696872085767828,
#  'year2ChangePercent': 0.7009037398579866,
#  'year1ChangePercent': 0.5252513251901025,
#  'ytdChangePercent': 0.1686816689589407,
#  'month6ChangePercent': 0.14495070072295396,
#  'month3ChangePercent': 0.19002784916805004,
#  'month1ChangePercent': 0.021227224211726275,
#  'day30ChangePercent': 0.022142018668580933,
#  'day5ChangePercent': -0.01859074104810315}

# %% [markdown]
# ## Parsing Our API Call
#
# This API call has all the information we need. We can parse it using the same square-bracket notation as in the first project of this course. Here is an example.

# %% [markdown]
# ## Executing A Batch API Call & Building Our DataFrame
#
# Just like in our first project, it's now time to execute several batch API calls and add the information we need to our DataFrame.
#
# We'll start by running the following code cell, which contains some code we already built last time that we can re-use for this project. More specifically, it contains a function called `chunks` that we can use to divide our list of securities into groups of 100.

# %%
# Function sourced from 
# https://stackoverflow.com/questions/312443/how-do-you-split-a-list-into-evenly-sized-chunks
def chunks(lst, n):
    """Yield successive n-sized chunks from lst."""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]   

    
symbol_groups = list(chunks(stocks_df['Ticker'], 100))
symbol_strings = []


for i in range(0, len(symbol_groups)):
    symbol_strings.append(','.join(symbol_groups[i]))
   
    
#     /stock/market/batch?symbols=aapl,fb,tsla&types=quote,news,chart&range=1m&last=5
    print(symbol_strings[i]) #string batches
my_columns = ['Ticker', 'Price', 'One-Year Price Return', 'Number of Shares to Buy']
# Out:
# Ticker                        A
# Year 1 Price Change    0.711552
# dtype: object
# Ticker                      AAL
# Year 1 Price Change    1.174265
# dtype: object
# Ticker                      AAP
# Year 1 Price Change    0.648774
# dtype: object
# Ticker                     AAPL
# Year 1 Price Change    0.694003
# dtype: object
# Ticker                     ABBV
# Year 1 Price Change    0.460142
# dtype: object
# Ticker                      ABC
# Year 1 Price Change    0.400439
# dtype: object
# Ticker                     ABMD
# Year 1 Price Change    0.593936
# dtype: object
# Ticker                      ABT
# Year 1 Price Change    0.292602
# dtype: object
# Ticker                      ACN
# Year 1 Price Change    0.594792
# dtype: object
# Ticker                     ADBE
# Year 1 Price Change    0.340906
# dtype: object
# Ticker                      ADI
# Year 1 Price Change    0.472666
# dtype: object
# Ticker                      ADM
# Year 1 Price Change    0.943119
# dtype: object
# Ticker                      ADP
# Year 1 Price Change    0.365906
# dtype: object
# Ticker                     ADSK
# Year 1 Price Change    0.556178
# dtype: object
# Ticker                      AEE
# Year 1 Price Change    0.224195
# dtype: object
# Ticker                      AEP
# Year 1 Price Change    0.134244
# dtype: object
# Ticker                      AES
# Year 1 Price Change    1.106087
# dtype: object
# Ticker                      AFL
# Year 1 Price Change    0.597261
# dtype: object
# Ticker                      AIG
# Year 1 Price Change    0.955666
# dtype: object
# Ticker                      AIV
# Year 1 Price Change    0.461334
# dtype: object
# Ticker                      AIZ
# Year 1 Price Change    0.654922
# dtype: object
# Ticker                      AJG
# Year 1 Price Change    0.795693
# dtype: object
# Ticker                     AKAM
# Year 1 Price Change    0.096614
# dtype: object
# Ticker                     ALB
# Year 1 Price Change    1.59294
# dtype: object
# Ticker                     ALGN
# Year 1 Price Change    1.865743
# dtype: object
# Ticker                      ALK
# Year 1 Price Change    1.277815
# dtype: object
# Ticker                      ALL
# Year 1 Price Change    0.345462
# dtype: object
# Ticker                     ALLE
# Year 1 Price Change    0.415398
# dtype: object
# Ticker                     ALXN
# Year 1 Price Change    0.773954
# dtype: object
# Ticker                    AMAT
# Year 1 Price Change    1.52395
# dtype: object
# Ticker                     AMCR
# Year 1 Price Change    0.469208
# dtype: object
# Ticker                     AMD
# Year 1 Price Change    0.50384
# dtype: object
# Ticker                      AME
# Year 1 Price Change    0.650755
# dtype: object
# Ticker                     AMGN
# Year 1 Price Change    0.113563
# dtype: object
# Ticker                      AMP
# Year 1 Price Change    1.230005
# dtype: object
# Ticker                      AMT
# Year 1 Price Change    0.059925
# dtype: object
# Ticker                     AMZN
# Year 1 Price Change    0.387674
# dtype: object
# Ticker                     ANET
# Year 1 Price Change    0.515368
# dtype: object
# Ticker                    ANSS
# Year 1 Price Change    0.27108
# dtype: object
# Ticker                     ANTM
# Year 1 Price Change    0.473153
# dtype: object
# Ticker                      AON
# Year 1 Price Change    0.374799
# dtype: object
# Ticker                     AOS
# Year 1 Price Change    0.64562
# dtype: object
# Ticker                      APA
# Year 1 Price Change    0.110418
# dtype: object
# Ticker                      APD
# Year 1 Price Change    0.277054
# dtype: object
# Ticker                     APH
# Year 1 Price Change    0.55305
# dtype: object
# Ticker                     APTV
# Year 1 Price Change    1.236312
# dtype: object
# Ticker                      ARE
# Year 1 Price Change    0.204552
# dtype: object
# Ticker                      ATO
# Year 1 Price Change    0.078634
# dtype: object
# Ticker                     ATVI
# Year 1 Price Change    0.312968
# dtype: object
# Ticker                      AVB
# Year 1 Price Change    0.246283
# dtype: object
# Ticker                     AVGO
# Year 1 Price Change    0.716725
# dtype: object
# Ticker                      AVY
# Year 1 Price Change    1.093347
# dtype: object
# Ticker                      AWK
# Year 1 Price Change    0.326276
# dtype: object
# Ticker                      AXP
# Year 1 Price Change    0.812483
# dtype: object
# Ticker                     AZO
# Year 1 Price Change    0.44392
# dtype: object
# Ticker                       BA
# Year 1 Price Change    0.765516
# dtype: object
# Ticker                      BAC
# Year 1 Price Change    0.840163
# dtype: object
# Ticker                      BAX
# Year 1 Price Change   -0.004997
# dtype: object
# Ticker                      BBY
# Year 1 Price Change    0.601451
# dtype: object
# Ticker                      BDX
# Year 1 Price Change   -0.052026
# dtype: object
# Ticker                      BEN
# Year 1 Price Change    0.862711
# dtype: object
# Ticker                     BF.B
# Year 1 Price Change    0.177067
# dtype: object
# Ticker                     BIIB
# Year 1 Price Change   -0.131777
# dtype: object
# Ticker                      BIO
# Year 1 Price Change    0.345805
# dtype: object
# Ticker                       BK
# Year 1 Price Change    0.530731
# dtype: object
# Ticker                     BKNG
# Year 1 Price Change    0.631518
# dtype: object
# Ticker                      BKR
# Year 1 Price Change    0.735048
# dtype: object
# Ticker                      BLK
# Year 1 Price Change    0.832897
# dtype: object
# Ticker                      BLL
# Year 1 Price Change    0.433249
# dtype: object
# Ticker                      BMY
# Year 1 Price Change    0.089632
# dtype: object
# Ticker                       BR
# Year 1 Price Change    0.429477
# dtype: object
# Ticker                    BRK.B
# Year 1 Price Change    0.672901
# dtype: object
# Ticker                      BSX
# Year 1 Price Change    0.134427
# dtype: object
# Ticker                      BWA
# Year 1 Price Change    0.868169
# dtype: object
# Ticker                      BXP
# Year 1 Price Change    0.308078
# dtype: object
# Ticker                        C
# Year 1 Price Change    0.708214
# dtype: object
# Ticker                      CAG
# Year 1 Price Change    0.165616
# dtype: object
# Ticker                      CAH
# Year 1 Price Change    0.213825
# dtype: object
# Ticker                     CARR
# Year 1 Price Change    1.537598
# dtype: object
# Ticker                      CAT
# Year 1 Price Change    1.243985
# dtype: object
# Ticker                       CB
# Year 1 Price Change    0.783039
# dtype: object
# Ticker                     CBOE
# Year 1 Price Change    0.085156
# dtype: object
# Ticker                     CBRE
# Year 1 Price Change    1.141531
# dtype: object
# Ticker                      CCI
# Year 1 Price Change    0.206319
# dtype: object
# Ticker                      CCL
# Year 1 Price Change    0.890949
# dtype: object
# Ticker                    CDNS
# Year 1 Price Change    0.58476
# dtype: object
# Ticker                      CDW
# Year 1 Price Change    0.636829
# dtype: object
# Ticker                       CE
# Year 1 Price Change    1.110203
# dtype: object
# Ticker                     CERN
# Year 1 Price Change    0.133109
# dtype: object
# Ticker                       CF
# Year 1 Price Change    0.980845
# dtype: object
# Ticker                      CFG
# Year 1 Price Change    1.355087
# dtype: object
# Ticker                      CHD
# Year 1 Price Change    0.209233
# dtype: object
# Ticker                     CHRW
# Year 1 Price Change    0.380896
# dtype: object
# Ticker                     CHTR
# Year 1 Price Change    0.360773
# dtype: object
# Ticker                       CI
# Year 1 Price Change    0.399817
# dtype: object
# Ticker                     CINF
# Year 1 Price Change    1.287056
# dtype: object
# Ticker                       CL
# Year 1 Price Change    0.216434
# dtype: object
# Ticker                      CLX
# Year 1 Price Change   -0.086315
# dtype: object
# Ticker                      CMA
# Year 1 Price Change    1.508926
# dtype: object
# Ticker                    CMCSA
# Year 1 Price Change    0.639291
# dtype: object
# {'A': {'stats': {'companyName': 'Agilent Technologies Inc.', 'marketcap': 42511971697, 'week52high': 138.81, 'week52low': 82.07, 'week52highSplitAdjustOnly': 144.26, 'week52lowSplitAdjustOnly': 80.51, 'week52change': 0.711648326661438, 'sharesOutstanding': 312493996, 'float': 0, 'avg10Volume': 1261122, 'avg30Volume': 1645170, 'day200MovingAvg': 127.06, 'day50MovingAvg': 134.77, 'employees': 0, 'ttmEPS': 2.6, 'ttmDividendRate': 0.7808747133757312, 'dividendYield': 0.005685703563478624, 'nextDividendDate': '0', 'exDividendDate': '2021-03-31', 'nextEarningsDate': '2021-05-24', 'peRatio': 51.2158336390646, 'beta': 0.9039972272008233, 'maxChangePercent': 4.85436657459654, 'year5ChangePercent': 2.4452408010525706, 'year2ChangePercent': 0.793909866310686, 'year1ChangePercent': 0.711552301582413, 'ytdChangePercent': 0.1396050765206955, 'month6ChangePercent': 0.2023692873777978, 'month3ChangePercent': 0.0921780066072054, 'month1ChangePercent': 0.015213114807575891, 'day30ChangePercent': 0.015363854110496017, 'day5ChangePercent': 0.002008335353950676}}, 'AAL': {'stats': {'companyName': 'American Airlines Group Inc', 'marketcap': 14789598711, 'week52high': 27.33, 'week52low': 8.33, 'week52highSplitAdjustOnly': 26.32, 'week52lowSplitAdjustOnly': 8.59, 'week52change': 1.2257420241177315, 'sharesOutstanding': 660356865, 'float': 0, 'avg10Volume': 30330366, 'avg30Volume': 36342678, 'day200MovingAvg': 18.81, 'day50MovingAvg': 22.75, 'employees': 136756, 'ttmEPS': -15.07, 'ttmDividendRate': 0, 'dividendYield': 0, 'nextDividendDate': '0', 'exDividendDate': '0', 'nextEarningsDate': '2021-07-18', 'peRatio': -1.799378714961645, 'beta': 1.6601662858901076, 'maxChangePercent': -0.0538946100888849, 'year5ChangePercent': -0.3143370286909979, 'year2ChangePercent': -0.3585071227214525, 'year1ChangePercent': 1.174264899943527, 'ytdChangePercent': 0.4123208367462335, 'month6ChangePercent': 0.685400947996737, 'month3ChangePercent': 0.2660352779382198, 'month1ChangePercent': -0.0657865609258116, 'day30ChangePercent': -0.06773146656025338, 'day5ChangePercent': 0.013419439453769258}}, 'AAP': {'stats': {'companyName': 'Advance Auto Parts Inc', 'marketcap': 13621298979, 'week52high': 207.2, 'week52low': 120.8, 'week52highSplitAdjustOnly': 211.2, 'week52lowSplitAdjustOnly': 118.58, 'week52change': 0.6581837256650204, 'sharesOutstanding': 67853776, 'float': 0, 'avg10Volume': 592324, 'avg30Volume': 749348, 'day200MovingAvg': 167.8, 'day50MovingAvg': 197.29, 'employees': 0, 'ttmEPS': 7.45, 'ttmDividendRate': 1.0291316455646378, 'dividendYield': 0.004968950037656059, 'nextDividendDate': '2021-06-15', 'exDividendDate': '2021-03-13', 'nextEarningsDate': '2021-05-20', 'peRatio': 27.55906766961274, 'beta': 0.8150694983448024, 'maxChangePercent': 4.417452523638598, 'year5ChangePercent': 0.3798734920395905, 'year2ChangePercent': 0.2970281170085783, 'year1ChangePercent': 0.6487736114740569, 'ytdChangePercent': 0.2999613375829309, 'month6ChangePercent': 0.31763009948890447, 'month3ChangePercent': 0.28426175683172944, 'month1ChangePercent': 0.11245488716634465, 'day30ChangePercent': 0.11425822037797452, 'day5ChangePercent': 0.02224289311137583}}, 'AAPL': {'stats': {'companyName': 'Apple Inc', 'marketcap': 2240402078179, 'week52high': 148.57, 'week52low': 78.14, 'week52highSplitAdjustOnly': 147.37, 'week52lowSplitAdjustOnly': 78.3, 'week52change': 0.7040499578255317, 'sharesOutstanding': 16727102275, 'float': 0, 'avg10Volume': 93963058, 'avg30Volume': 93665861, 'day200MovingAvg': 127.72, 'day50MovingAvg': 131.28, 'employees': 147489, 'ttmEPS': 4.45, 'ttmDividendRate': 0.8682347030359546, 'dividendYield': 0.006701929550216871, 'nextDividendDate': '0', 'exDividendDate': '2021-04-24', 'nextEarningsDate': '2021-07-25', 'peRatio': 28.610605564280238, 'beta': 1.38441637173479, 'maxChangePercent': 50.92479621146042, 'year5ChangePercent': 5.160146676148705, 'year2ChangePercent': 1.7129872146216523, 'year1ChangePercent': 0.6940029475148161, 'ytdChangePercent': -0.015628140544543888, ' ...
# A,AAL,AAP,AAPL,ABBV,ABC,ABMD,ABT,ACN,ADBE,ADI,ADM,ADP,ADSK,AEE,AEP,AES,AFL,AIG,AIV,AIZ,AJG,AKAM,ALB,ALGN,ALK,ALL,ALLE,ALXN,AMAT,AMCR,AMD,AME,AMGN,AMP,AMT,AMZN,ANET,ANSS,ANTM,AON,AOS,APA,APD,APH,APTV,ARE,ATO,ATVI,AVB,AVGO,AVY,AWK,AXP,AZO,BA,BAC,BAX,BBY,BDX,BEN,BF.B,BIIB,BIO,BK,BKNG,BKR,BLK,BLL,BMY,BR,BRK.B,BSX,BWA,BXP,C,CAG,CAH,CARR,CAT,CB,CBOE,CBRE,CCI,CCL,CDNS,CDW,CE,CERN,CF,CFG,CHD,CHRW,CHTR,CI,CINF,CL,CLX,CMA,CMCSA
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-99e77d3a58d8> in <module>
#      17 #     print(data)
#      18     for ticker in data:
# ---> 19         row = pd.Series([ticker, data[ticker]['stats']['year1ChangePercent']], index=["Ticker", "Year 1 Price Change"])
#      20         print(row)
#      21 #         stocks_df = stocks_df.append(row)
#
# TypeError: string indices must be integers

# %% [markdown]
# Now we need to create a blank DataFrame and add our data to the data frame one-by-one.

# %%
final_df = pd.DataFrame(columns=my_columns)

for symbol_string in symbol_groups:
    symbol_string = ",".join(symbol_string)
#     print(symbol_string)
    params={"symbols":symbol_string, "types":"stats", "token":IEX_CLOUD_SANDBOX_API_TOKEN}
    response = requests.get(f"{base_url}/stable/stock/market/batch", params=params)
   
    data = response.json()
#     print(data)
    for ticker in symbol_string.split(',')
        row = pd.Series([ticker, data[ticker]['stats']['year1ChangePercent'], ], index=my_columns)
        print(row)
        stocks_df = stocks_df.append(row)
        pass
#     print(response.json())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-16ee5c6f273b> in <module>
#      10 #     print(data)
#      11     for ticker in data:
# ---> 12         row = pd.Series([ticker, data[ticker]['stats']['year1ChangePercent']], index=my_columns)
#      13         print(row)
#      14         stocks_df = stocks_df.append(row)
#
# ~/projects/algorithmic_trading/momentum_trading_strat/venv/lib/python3.8/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     348                 try:
#     349                     if len(index) != len(data):
# --> 350                         raise ValueError(
#     351                             f"Length of passed values is {len(data)}, "
#     352                             f"index implies {len(index)}."
#
# ValueError: Length of passed values is 2, index implies 4.

# %% [markdown]
# ## Removing Low-Momentum Stocks
#
# The investment strategy that we're building seeks to identify the 50 highest-momentum stocks in the S&P 500.
#
# Because of this, the next thing we need to do is remove all the stocks in our DataFrame that fall below this momentum threshold. We'll sort the DataFrame by the stocks' one-year price return, and drop all stocks outside the top 50.

# %% [markdown]
# ## Calculating the Number of Shares to Buy
#
# Just like in the last project, we now need to calculate the number of shares we need to buy. The one change we're going to make is wrapping this functionality inside a function, since we'll be using it again later in this Jupyter Notebook.
#
# Since we've already done most of the work on this, try to complete the following two code cells without watching me do it first!

# %% [markdown]
# ## Building a Better (and More Realistic) Momentum Strategy
#
# Real-world quantitative investment firms differentiate between "high quality" and "low quality" momentum stocks:
#
# * High-quality momentum stocks show "slow and steady" outperformance over long periods of time
# * Low-quality momentum stocks might not show any momentum for a long time, and then surge upwards.
#
# The reason why high-quality momentum stocks are preferred is because low-quality momentum can often be cause by short-term news that is unlikely to be repeated in the future (such as an FDA approval for a biotechnology company).
#
# To identify high-quality momentum, we're going to build a strategy that selects stocks from the highest percentiles of:
#
# * 1-month price returns
# * 3-month price returns
# * 6-month price returns
# * 1-year price returns
#
# Let's start by building our DataFrame. You'll notice that I use the abbreviation `hqm` often. It stands for `high-quality momentum`.

# %% [markdown]
# ## Calculating Momentum Percentiles
#
# We now need to calculate momentum percentile scores for every stock in the universe. More specifically, we need to calculate percentile scores for the following metrics for every stock:
#
# * `One-Year Price Return`
# * `Six-Month Price Return`
# * `Three-Month Price Return`
# * `One-Month Price Return`
#
# Here's how we'll do this:

# %% [markdown]
# ## Calculating the HQM Score
#
# We'll now calculate our `HQM Score`, which is the high-quality momentum score that we'll use to filter for stocks in this investing strategy.
#
# The `HQM Score` will be the arithmetic mean of the 4 momentum percentile scores that we calculated in the last section.
#
# To calculate arithmetic mean, we will use the `mean` function from Python's built-in `statistics` module.

# %% [markdown]
# ## Selecting the 50 Best Momentum Stocks
#
# As before, we can identify the 50 best momentum stocks in our universe by sorting the DataFrame on the `HQM Score` column and dropping all but the top 50 entries.

# %% [markdown]
# ## Calculating the Number of Shares to Buy
#
# We'll use the `portfolio_input` function that we created earlier to accept our portfolio size. Then we will use similar logic in a `for` loop to calculate the number of shares to buy for each stock in our investment universe.

# %% [markdown]
# ## Formatting Our Excel Output
#
# We will be using the XlsxWriter library for Python to create nicely-formatted Excel files.
#
# XlsxWriter is an excellent package and offers tons of customization. However, the tradeoff for this is that the library can seem very complicated to new users. Accordingly, this section will be fairly long because I want to do a good job of explaining how XlsxWriter works.

# %% [markdown]
# ## Creating the Formats We'll Need For Our .xlsx File
#
# You'll recall from our first project that formats include colors, fonts, and also symbols like % and $. We'll need four main formats for our Excel document:
#
# * String format for tickers
# * \$XX.XX format for stock prices
# * \$XX,XXX format for market capitalization
# * Integer format for the number of shares to purchase
#
# Since we already built our formats in the last section of this course, I've included them below for you. Run this code cell before proceeding.

# %%
background_color = '#0a0a23'
font_color = '#ffffff'

string_template = writer.book.add_format(
        {
            'font_color': font_color,
            'bg_color': background_color,
            'border': 1
        }
    )

dollar_template = writer.book.add_format(
        {
            'num_format':'$0.00',
            'font_color': font_color,
            'bg_color': background_color,
            'border': 1
        }
    )

integer_template = writer.book.add_format(
        {
            'num_format':'0',
            'font_color': font_color,
            'bg_color': background_color,
            'border': 1
        }
    )

percent_template = writer.book.add_format(
        {
            'num_format':'0.0%',
            'font_color': font_color,
            'bg_color': background_color,
            'border': 1
        }
    )

# %% [markdown]
# ## Saving Our Excel Output
#
# As before, saving our Excel output is very easy:
